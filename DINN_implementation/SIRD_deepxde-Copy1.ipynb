# %%
import deepxde as dde
import numpy as np
from deepxde.backend import pytorch
import torch
import matplotlib.pyplot as plt
from SIRD_deepxde_class import SIRD_deepxde_net
from SIRD_deepxde_class import Plot
# Out:
# Using backend: pytorch

# %% [markdown]
# # Create synthetic data

# %%
alpha_real = 0.2
beta_real = 0.05
gamma_real = 0.01

# %%
import ODE_SIR
solver = ODE_SIR.ODESolver()
t_synth, wsol_synth, N = solver.solve_SIRD(alpha_real, beta_real, gamma_real)
solver.plot_SIRD(t_synth, wsol_synth)
# Out:
# total  [2.04643018e+05 1.47928048e+03 3.99489808e+06 7.98979617e+05]
# total  4999999.999999996

# %% [markdown]
# Use cell below if we want to subset timestep - ie simulate if we are at an early stage in the pandemic so have limited data

# %%
# keep this even if not subsetting
t = t_synth
wsol = wsol_synth

# subset
max_timestep = 100
t_bool = t_synth < max_timestep
t = t_synth[t_bool]
wsol = wsol_synth[t_bool]

# %% [markdown]
# # Create model
# Code has been wrapped in a custom class that wraps around the deepxde model

# %%
model = SIRD_deepxde_net(t, wsol)

# %%
model.init_model(print_every=1000)
# Out:
# Compiling model...
# 'compile' took 0.001645 s

# %%
model.train_model(iterations=10000)
# Out:
# Training model...
#
# Step      Train loss                                                                                                                  Test loss                                                                                                                   Test metric
# 0         [1.26e-03, 1.29e-02, 1.18e-02, 2.06e-03, 1.00e+00, 4.00e-12, 0.00e+00, 0.00e+00, 8.54e-01, 2.53e-01, 1.08e+00, 7.45e-03]    [1.26e-03, 1.29e-02, 1.18e-02, 2.06e-03, 1.00e+00, 4.00e-12, 0.00e+00, 0.00e+00, 8.54e-01, 2.53e-01, 1.08e+00, 7.45e-03]    []
# 0 [1.00e-01, 1.00e-01, 1.00e-01]
# 1000      [1.68e-06, 1.26e-06, 1.81e-06, 7.50e-07, 1.24e-06, 2.64e-08, 1.09e-06, 6.62e-06, 1.79e-04, 4.27e-05, 8.19e-05, 2.21e-05]    [1.68e-06, 1.26e-06, 1.81e-06, 7.50e-07, 1.24e-06, 2.64e-08, 1.09e-06, 6.62e-06, 1.79e-04, 4.27e-05, 8.19e-05, 2.21e-05]    []
# 1000 [1.83e-01, 3.64e-02, 5.90e-03]
# 2000      [3.95e-06, 2.25e-06, 5.95e-07, 2.06e-06, 1.02e-04, 3.11e-06, 4.54e-05, 2.25e-04, 2.97e-03, 4.98e-04, 6.09e-04, 2.30e-04]    [3.95e-06, 2.25e-06, 5.95e-07, 2.06e-06, 1.02e-04, 3.11e-06, 4.54e-05, 2.25e-04, 2.97e-03, 4.98e-04, 6.09e-04, 2.30e-04]    []
# 2000 [1.88e-01, 4.15e-02, 4.89e-03]
# 3000      [5.18e-06, 1.42e-06, 1.89e-06, 7.54e-07, 5.00e-06, 1.01e-05, 4.46e-06, 4.57e-05, 6.59e-05, 3.48e-05, 2.69e-05, 3.89e-05]    [5.18e-06, 1.42e-06, 1.89e-06, 7.54e-07, 5.00e-06, 1.01e-05, 4.46e-06, 4.57e-05, 6.59e-05, 3.48e-05, 2.69e-05, 3.89e-05]    []
# 3000 [1.75e-01, 4.49e-02, 1.07e-02]
# 4000      [2.13e-06, 9.78e-07, 1.74e-06, 3.01e-07, 6.21e-06, 4.78e-06, 2.34e-05, 3.98e-06, 4.86e-05, 3.49e-05, 4.91e-05, 6.12e-06]    [2.13e-06, 9.78e-07, 1.74e-06, 3.01e-07, 6.21e-06, 4.78e-06, 2.34e-05, 3.98e-06, 4.86e-05, 3.49e-05, 4.91e-05, 6.12e-06]    []
# 4000 [1.99e-01, 4.31e-02, 7.72e-03]
# 5000      [1.59e-06, 1.34e-06, 1.92e-06, 2.51e-07, 4.14e-05, 1.79e-05, 1.59e-06, 4.05e-05, 1.47e-03, 3.32e-04, 3.30e-04, 1.04e-05]    [1.59e-06, 1.34e-06, 1.92e-06, 2.51e-07, 4.14e-05, 1.79e-05, 1.59e-06, 4.05e-05, 1.47e-03, 3.32e-04, 3.30e-04, 1.04e-05]    []
# 5000 [1.98e-01, 4.42e-02, 8.31e-03]
# 6000      [1.51e-06, 3.76e-07, 1.43e-06, 2.84e-07, 2.46e-07, 3.16e-06, 2.96e-09, 1.92e-06, 7.18e-05, 2.18e-05, 2.59e-05, 3.97e-06]    [1.51e-06, 3.76e-07, 1.43e-06, 2.84e-07, 2.46e-07, 3.16e-06, 2.96e-09, 1.92e-06, 7.18e-05, 2.18e-05, 2.59e-05, 3.97e-06]    []
# 6000 [1.81e-01, 4.32e-02, 7.03e-03]
# 7000      [3.45e-06, 2.30e-06, 3.43e-06, 3.23e-06, 5.44e-07, 2.93e-07, 3.50e-07, 1.27e-07, 6.51e-05, 3.07e-05, 4.69e-05, 8.84e-06]    [3.45e-06, 2.30e-06, 3.43e-06, 3.23e-06, 5.44e-07, 2.93e-07, 3.50e-07, 1.27e-07, 6.51e-05, 3.07e-05, 4.69e-05, 8.84e-06]    []
# 7000 [1.84e-01, 3.72e-02, 1.02e-02]
# 8000      [1.34e-06, 9.94e-07, 9.49e-07, 9.70e-08, 1.63e-05, 1.57e-05, 5.80e-05, 2.67e-05, 1.14e-03, 2.88e-04, 3.74e-04, 4.62e-05]    [1.34e-06, 9.94e-07, 9.49e-07, 9.70e-08, 1.63e-05, 1.57e-05, 5.80e-05, 2.67e-05, 1.14e-03, 2.88e-04, 3.74e-04, 4.62e-05]    []
# 8000 [1.91e-01, 4.29e-02, 8.30e-03]
# 9000      [2.35e-06, 4.01e-07, 2.61e-06, 1.45e-07, 3.72e-08, 9.09e-09, 1.89e-07, 3.40e-09, 1.02e-05, 1.95e-06, 1.12e-05, 4.49e-07]    [2.35e-06, 4.01e-07, 2.61e-06, 1.45e-07, 3.72e-08, 9.09e-09, 1.89e-07, 3.40e-09, 1.02e-05, 1.95e-06, 1.12e-05, 4.49e-07]    []
# 9000 [1.85e-01, 4.27e-02, 8.84e-03]
# 10000     [1.68e-06, 3.71e-07, 1.48e-06, 7.15e-08, 7.36e-07, 2.06e-08, 3.01e-07, 1.08e-06, 1.25e-05, 2.75e-06, 5.84e-06, 8.12e-07]    [1.68e-06, 3.71e-07, 1.48e-06, 7.15e-08, 7.36e-07, 2.06e-08, 3.01e-07, 1.08e-06, 1.25e-05, 2.75e-06, 5.84e-06, 8.12e-07]    []
# 10000 [1.95e-01, 4.55e-02, 1.03e-02]
#
# Best model at step 10000:
#   train loss: 2.77e-05
#   test loss: 2.77e-05
#   test metric: []
#
# 'train' took 472.847395 s

# %% [markdown]
# # Investigate output
# First use the predicted parameters from the neural network to solve the ODE

# %%
alpha_nn, beta_nn, gamma_nn = model.get_predicted_params()
t_nn_param, wsol_nn_param, N_nn_param = solver.solve_SIRD(alpha_nn, beta_nn, gamma_nn)

# %%
# we need to set the synthetic data as it comes from outside the network
# the two functions below sets the synthetic data
model.set_synthetic_data(t_synth, wsol_synth) 
model.set_nn_synthetic_data(t_nn_param, wsol_nn_param)

# %%
plot = Plot(model) # class that contains plotting functions

# %% [markdown]
# The plots below show two things:
# * A comparison between the data we have and what the PINN predicts in this range
# * A comparison between the synthetic data in the whole range and the result from using the predicted parameters in the ODE solver

# %%
plot.show_known_and_prediction()

# %% [markdown]
# # Same as before with even less data
# The timing of the data is important. We want to predict as early as possible in the pandemic, so investigate what the effect is of having less data.

# %%
max_timestep = 85
t_bool = t_synth < max_timestep
t = t_synth[t_bool]
wsol = wsol_synth[t_bool]

# %%
model_less = SIRD_deepxde_net(t, wsol)
model_less.init_model(print_every=1000)
model_less.train_model(iterations=10000)
# Out:
# Compiling model...
# 'compile' took 0.001121 s
#
# Training model...
#
# Step      Train loss                                                                                                                  Test loss                                                                                                                   Test metric
# 0         [1.49e-03, 3.05e-02, 8.62e-03, 2.59e-02, 1.00e+00, 4.00e-12, 0.00e+00, 0.00e+00, 1.42e+00, 4.70e-01, 1.05e-01, 1.22e+00]    [1.49e-03, 3.05e-02, 8.62e-03, 2.59e-02, 1.00e+00, 4.00e-12, 0.00e+00, 0.00e+00, 1.42e+00, 4.70e-01, 1.05e-01, 1.22e+00]    []
# 0 [1.00e-01, 1.00e-01, 1.00e-01]
# 1000      [7.73e-05, 6.80e-06, 2.65e-06, 6.96e-06, 2.13e-05, 3.44e-05, 2.28e-06, 4.82e-05, 3.47e-03, 1.56e-03, 2.72e-04, 8.60e-04]    [7.73e-05, 6.80e-06, 2.65e-06, 6.96e-06, 2.13e-05, 3.44e-05, 2.28e-06, 4.82e-05, 3.47e-03, 1.56e-03, 2.72e-04, 8.60e-04]    []
# 1000 [-6.18e-03, 6.79e-03, 5.92e-03]
# 2000      [5.61e-06, 1.76e-06, 3.96e-07, 6.82e-07, 7.73e-09, 1.10e-08, 5.96e-09, 1.53e-12, 7.32e-04, 3.03e-04, 7.86e-05, 5.79e-06]    [5.61e-06, 1.76e-06, 3.96e-07, 6.82e-07, 7.73e-09, 1.10e-08, 5.96e-09, 1.53e-12, 7.32e-04, 3.03e-04, 7.86e-05, 5.79e-06]    []
# 2000 [6.19e-02, 9.45e-03, 2.47e-03]
# 3000      [2.06e-06, 7.86e-07, 9.57e-07, 1.88e-07, 9.61e-07, 1.29e-06, 1.17e-07, 4.88e-07, 9.12e-05, 3.39e-05, 1.59e-05, 1.58e-06]    [2.06e-06, 7.86e-07, 9.57e-07, 1.88e-07, 9.61e-07, 1.29e-06, 1.17e-07, 4.88e-07, 9.12e-05, 3.39e-05, 1.59e-05, 1.58e-06]    []
# 3000 [1.37e-01, 3.38e-02, 3.11e-03]
# 4000      [4.86e-05, 8.89e-06, 3.48e-06, 3.08e-05, 3.29e-03, 2.45e-04, 6.95e-06, 4.93e-06, 3.35e-03, 1.87e-03, 3.08e-04, 2.59e-05]    [4.86e-05, 8.89e-06, 3.48e-06, 3.08e-05, 3.29e-03, 2.45e-04, 6.95e-06, 4.93e-06, 3.35e-03, 1.87e-03, 3.08e-04, 2.59e-05]    []
# 4000 [9.17e-02, 2.55e-02, 2.94e-03]
# 5000      [3.93e-06, 5.15e-06, 3.82e-07, 2.93e-06, 2.48e-10, 2.76e-07, 1.38e-06, 3.65e-06, 9.41e-04, 4.24e-04, 1.10e-04, 8.26e-06]    [3.93e-06, 5.15e-06, 3.82e-07, 2.93e-06, 2.48e-10, 2.76e-07, 1.38e-06, 3.65e-06, 9.41e-04, 4.24e-04, 1.10e-04, 8.26e-06]    []
# 5000 [5.09e-02, 7.34e-03, -3.71e-04]
# 6000      [1.82e-04, 6.97e-06, 2.19e-06, 6.91e-06, 8.00e-04, 1.04e-04, 2.45e-05, 1.68e-05, 3.02e-03, 1.54e-03, 3.77e-04, 1.66e-05]    [1.82e-04, 6.97e-06, 2.19e-06, 6.91e-06, 8.00e-04, 1.04e-04, 2.45e-05, 1.68e-05, 3.02e-03, 1.54e-03, 3.77e-04, 1.66e-05]    []
# 6000 [1.11e-02, 6.89e-03, 4.42e-03]
# 7000      [3.10e-06, 1.12e-06, 5.49e-07, 1.21e-07, 1.91e-06, 1.95e-07, 7.16e-06, 7.22e-06, 3.27e-03, 1.44e-03, 2.57e-04, 1.52e-05]    [3.10e-06, 1.12e-06, 5.49e-07, 1.21e-07, 1.91e-06, 1.95e-07, 7.16e-06, 7.22e-06, 3.27e-03, 1.44e-03, 2.57e-04, 1.52e-05]    []
# 7000 [2.13e-02, 1.79e-02, 7.54e-03]
# 8000      [1.16e-07, 2.48e-08, 7.48e-08, 3.72e-08, 3.64e-04, 3.76e-04, 4.29e-06, 6.24e-05, 3.33e-03, 1.49e-03, 2.70e-04, 1.23e-04]    [1.16e-07, 2.48e-08, 7.48e-08, 3.72e-08, 3.64e-04, 3.76e-04, 4.29e-06, 6.24e-05, 3.33e-03, 1.49e-03, 2.70e-04, 1.23e-04]    []
# 8000 [1.03e-02, 2.24e-03, 1.44e-03]
# 9000      [1.48e-06, 5.85e-07, 1.09e-07, 6.96e-09, 5.09e-05, 2.20e-05, 5.31e-05, 9.03e-05, 7.59e-04, 3.21e-04, 1.36e-04, 8.51e-05]    [1.48e-06, 5.85e-07, 1.09e-07, 6.96e-09, 5.09e-05, 2.20e-05, 5.31e-05, 9.03e-05, 7.59e-04, 3.21e-04, 1.36e-04, 8.51e-05]    []
# 9000 [5.90e-02, 1.30e-02, 2.70e-04]
# 10000     [2.21e-06, 8.41e-07, 2.05e-07, 1.53e-08, 7.00e-09, 2.86e-06, 5.88e-07, 6.30e-05, 5.66e-05, 2.99e-05, 8.50e-06, 6.07e-05]    [2.21e-06, 8.41e-07, 2.05e-07, 1.53e-08, 7.00e-09, 2.86e-06, 5.88e-07, 6.30e-05, 5.66e-05, 2.99e-05, 8.50e-06, 6.07e-05]    []
# 10000 [1.37e-01, 3.27e-02, 6.03e-03]
#
# Best model at step 3000:
#   train loss: 1.49e-04
#   test loss: 1.49e-04
#   test metric: []
#
# 'train' took 362.852902 s

# %%
alpha_nn, beta_nn, gamma_nn = model_less.get_predicted_params()
print(f'Alpha: {alpha_nn}, beta: {beta_nn}, gamma: {gamma_nn}')
t_nn_param, wsol_nn_param, N_nn_param = solver.solve_SIRD(alpha_nn, beta_nn, gamma_nn)
# Out:
# Alpha: 0.13730916380882263, beta: 0.03274700418114662, gamma: 0.006028314586728811

# %%
model_less.set_synthetic_data(t_synth, wsol_synth)
model_less.set_nn_synthetic_data(t_nn_param, wsol_nn_param)
plot_less = Plot(model_less)

# %%
plot_less.show_known_and_prediction()

# %% [markdown]
# # Even less data

# %%
max_timestep = 75
t_bool = t_synth < max_timestep
t = t_synth[t_bool]
wsol = wsol_synth[t_bool]

# %%
model_less_2 = SIRD_deepxde_net(t, wsol)
model_less_2.init_model(print_every=1000)
model_less_2.train_model(iterations=10000)
# Out:
# Compiling model...
# 'compile' took 0.000365 s
#
# Training model...
#
# Step      Train loss                                                                                                                  Test loss                                                                                                                   Test metric
# 0         [2.15e-03, 1.41e-01, 2.26e-02, 2.75e-02, 1.00e+00, 4.00e-12, 0.00e+00, 0.00e+00, 1.48e+00, 2.31e+00, 1.03e-01, 4.27e-01]    [2.15e-03, 1.41e-01, 2.26e-02, 2.75e-02, 1.00e+00, 4.00e-12, 0.00e+00, 0.00e+00, 1.48e+00, 2.31e+00, 1.03e-01, 4.27e-01]    []
# 0 [1.00e-01, 1.00e-01, 1.00e-01]
# 1000      [1.92e-06, 9.08e-07, 8.64e-07, 1.74e-06, 3.45e-06, 1.53e-08, 6.57e-09, 1.11e-06, 1.46e-04, 4.58e-05, 6.16e-06, 8.39e-06]    [1.92e-06, 9.08e-07, 8.64e-07, 1.74e-06, 3.45e-06, 1.53e-08, 6.57e-09, 1.11e-06, 1.46e-04, 4.58e-05, 6.16e-06, 8.39e-06]    []
# 1000 [3.88e-02, 1.89e-02, 1.81e-02]
# 2000      [3.17e-06, 3.20e-07, 2.07e-07, 6.21e-07, 4.23e-08, 1.07e-09, 1.42e-08, 1.02e-08, 1.27e-04, 5.54e-05, 1.17e-05, 1.51e-06]    [3.17e-06, 3.20e-07, 2.07e-07, 6.21e-07, 4.23e-08, 1.07e-09, 1.42e-08, 1.02e-08, 1.27e-04, 5.54e-05, 1.17e-05, 1.51e-06]    []
# 2000 [4.62e-02, 1.56e-02, 1.37e-02]
# 3000      [1.95e-06, 2.26e-07, 1.57e-07, 8.37e-08, 8.25e-09, 2.24e-11, 4.82e-12, 6.02e-11, 9.55e-05, 4.59e-05, 8.14e-06, 5.08e-07]    [1.95e-06, 2.26e-07, 1.57e-07, 8.37e-08, 8.25e-09, 2.24e-11, 4.82e-12, 6.02e-11, 9.55e-05, 4.59e-05, 8.14e-06, 5.08e-07]    []
# 3000 [4.66e-02, 1.24e-02, 9.45e-03]
# 4000      [1.07e-06, 2.75e-07, 6.94e-08, 2.79e-08, 3.74e-08, 4.61e-09, 6.55e-10, 7.07e-12, 6.18e-05, 3.27e-05, 4.61e-06, 3.04e-07]    [1.07e-06, 2.75e-07, 6.94e-08, 2.79e-08, 3.74e-08, 4.61e-09, 6.55e-10, 7.07e-12, 6.18e-05, 3.27e-05, 4.61e-06, 3.04e-07]    []
# 4000 [5.38e-02, 1.04e-02, 5.87e-03]
# 5000      [1.52e-07, 1.58e-07, 2.29e-08, 1.54e-07, 3.19e-09, 4.80e-11, 7.49e-09, 1.85e-08, 3.00e-04, 1.37e-04, 2.20e-05, 7.38e-06]    [1.52e-07, 1.58e-07, 2.29e-08, 1.54e-07, 3.19e-09, 4.80e-11, 7.49e-09, 1.85e-08, 3.00e-04, 1.37e-04, 2.20e-05, 7.38e-06]    []
# 5000 [-5.42e-03, 4.57e-03, 6.93e-03]
# 6000      [1.34e-07, 3.56e-07, 2.68e-08, 1.68e-06, 2.54e-07, 2.55e-08, 9.10e-05, 2.28e-05, 2.25e-04, 1.08e-04, 1.07e-04, 2.41e-05]    [1.34e-07, 3.56e-07, 2.68e-08, 1.68e-06, 2.54e-07, 2.55e-08, 9.10e-05, 2.28e-05, 2.25e-04, 1.08e-04, 1.07e-04, 2.41e-05]    []
# 6000 [2.38e-02, 3.06e-03, 7.92e-04]
# 7000      [4.52e-07, 3.47e-07, 3.59e-07, 4.02e-08, 2.46e-06, 1.55e-06, 6.24e-08, 3.52e-06, 7.31e-05, 3.67e-05, 4.86e-06, 3.71e-06]    [4.52e-07, 3.47e-07, 3.59e-07, 4.02e-08, 2.46e-06, 1.55e-06, 6.24e-08, 3.52e-06, 7.31e-05, 3.67e-05, 4.86e-06, 3.71e-06]    []
# 7000 [4.74e-02, 8.77e-03, 8.19e-04]
# 8000      [2.66e-06, 1.40e-06, 2.14e-07, 1.23e-08, 2.15e-04, 2.32e-04, 1.48e-04, 3.11e-05, 4.61e-04, 3.67e-04, 1.78e-04, 2.70e-05]    [2.66e-06, 1.40e-06, 2.14e-07, 1.23e-08, 2.15e-04, 2.32e-04, 1.48e-04, 3.11e-05, 4.61e-04, 3.67e-04, 1.78e-04, 2.70e-05]    []
# 8000 [8.67e-02, 2.11e-02, 2.23e-03]
# 9000      [5.32e-07, 3.30e-07, 4.20e-08, 3.67e-08, 6.35e-05, 5.72e-05, 4.25e-05, 8.72e-08, 9.63e-05, 7.74e-05, 4.92e-05, 9.95e-08]    [5.32e-07, 3.30e-07, 4.20e-08, 3.67e-08, 6.35e-05, 5.72e-05, 4.25e-05, 8.72e-08, 9.63e-05, 7.74e-05, 4.92e-05, 9.95e-08]    []
# 9000 [1.01e-01, 2.27e-02, 6.20e-03]
# 10000     [5.17e-07, 2.03e-07, 1.78e-08, 2.01e-08, 1.45e-06, 1.62e-06, 1.78e-07, 3.68e-05, 8.99e-06, 5.74e-06, 1.07e-06, 4.29e-05]    [5.17e-07, 2.03e-07, 1.78e-08, 2.01e-08, 1.45e-06, 1.62e-06, 1.78e-07, 3.68e-05, 8.99e-06, 5.74e-06, 1.07e-06, 4.29e-05]    []
# 10000 [1.00e-01, 2.40e-02, 8.17e-03]
#
# Best model at step 10000:
#   train loss: 9.95e-05
#   test loss: 9.95e-05
#   test metric: []
#
# 'train' took 340.485141 s

# %%
alpha_nn, beta_nn, gamma_nn = model_less_2.get_predicted_params()
print(f'Alpha: {alpha_nn}, beta: {beta_nn}, gamma: {gamma_nn}')
t_nn_param, wsol_nn_param, N_nn_param = solver.solve_SIRD(alpha_nn, beta_nn, gamma_nn)
# Out:
# Alpha: 0.10022514313459396, beta: 0.023999202996492386, gamma: 0.008168422617018223

# %%
model_less_2.set_synthetic_data(t_synth, wsol_synth)
model_less_2.set_nn_synthetic_data(t_nn_param, wsol_nn_param)
plot_less_2 = Plot(model_less_2)

# %%
plot_less.show_known_and_prediction()

# %% [markdown]
# # Plot all together

# %%
fig, ax = plt.subplots()
plot._plot_pred_synthetic(ax)
for plotter, linestyle in zip([plot, plot_less, plot_less_2],['--','-.',':']):
    plotter._plot_pred_nn(ax, linestyle=linestyle)
